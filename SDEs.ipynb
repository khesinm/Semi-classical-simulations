# %%
import numpy as np
import sdeint
import matplotlib.pyplot as plt

a = 1.0
b = 0.8
tspan = np.linspace(0.0, 5.0, 5001)
x0 = 0.1

def f(x, t):
#     return -(a + x*b**2)*(1 - x**2)
    return x

def g(x, t):
    return b*(1 - x**2)*.5

def g2(x, t):
    return b*(1 - x**2)*0

def g3 (x,t):
    return g(x,t) + g2(x,t)
result = sdeint.itoint(f, g3, x0, tspan)


# print (result[0])
plt.plot(result)
plt.plot(result2)
